# %% [markdown]
# <a href="https://colab.research.google.com/github/lukmanawaludin/prak-pemrograman-visual/blob/main/Procedure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><b>PROCEDURE</b></h1>
#
# <hr>
# <h5><b>KOMPETENSI :</b></h5>
#
# Procedure
# <hr>
#
# <h5><b>MAKSUD DAN TUJUAN :</b></h5>
#
# Setelah mempelajari bab ini, diharapkan mampu:
# 1. Memahami dan mengenal Procedure
# 2. Dapat membuat aplikasi sederhana dengan menggunakan Procedure
#
# <hr>
#
# <h5><b>PROCEDURE</b></h5>
#
# 1. Merupakan Sub program yang digunakan untuk
# melakukan proses tertentu
# 2. Procedure dapat disimpan dalam basis data sebagai object
# skema, maka suatu procedure bisa digunakan berulang-ulang tanpa harus melakukan parsing dan meng-compile ulang
# 3. Disebut juga sebagai sebuah blok program yang di dalamnya dapat menuliskan kode-kode program
#
# <h6><b>Jenis Procedure dalam Visual Basic :</b></h6>
#
# 1. Procedure Sub -> Procedure yang tidak mengembalikan nilai
# 2. Procedure Function -> Procedure yang mengembalikan nilai
# 3. Procedure Property -> Procedure yang dapat mengembalikan dan menugaskan nilai serta dapat mengeset referensi ke object
# 4. Procedur Event -> Procedure untuk suatu event pada sebuah object, digunakan dalam Class
# Module
#
# <hr>
# <h6><b>Procedure Sub</b></h6>
#
# Sejauh ini, anda telah menuliskan procedure sub yang dibuat secara otomatis pada saat menggunakan event. Sub procedure merupakan blok kode yang mempunyai nama dan berisi perintah yang dapat dipanggil suatu waktu. Artinya, hanya sekali dibuat yang kemudian di
# panggil berkali-kali sesuai dengan kebutuhan.
#
# Dengan memecah kode yang terdapat di dalam sebuah module ke dalam prosedur Sub, maka akan menjadikan kode lebih mudah untuk ditemukan atau dimodifikasi di dalam aplikasi.

# %%
[Public|Private][Static]Sub namaprocedure (argumentlist)
    Statements
    ....
End Sub

# %% [markdown]
# <h6><b>Procedure Function</b></h6>
# Visual Basic menyertakan function bawaan atau intrinsic function,
# seperti:

# %%
 Sqr, Cos or Chr

# %% [markdown]
# Selain itu, pernyataan Function dapat digunakan untuk menulis
# Procedure Function milik sendiri.

# %%
[Public|Private][Static]Function procedurename (argumens) [As Type]
    Statements
    ....
End Sub

# %% [markdown]
# ***Public dan Private***
#
# Pernyataan:

# %%
[public|private]

# %% [markdown]
# menyatakan ruang lingkup **(scope)** kerja procedure. Jika procedure berada pada scope public berarti digunakan dalam lingkup project **(Global Procedure Global)**. Jika procedure pada scope private berarti digunakan dalam lingkup form itu sendiri, tidak bisa diakses oleh form lain **(Local Procedure)**
# <hr>

# %% [markdown]
# <b><h6>General Procedure</h6></b>
#
# 1. Procedure yang ditulis pada bagian general sebuah form
# 2. General procedure dapat mendefiniskan sendiri nama dan procedure tersebut
# 3. General procedure biasanya dipanggil dari event procedure

# %%
[Public|Private] Sub <Procedure_name>(Parameter)
    <Pernyataan>
    ...
    <Pernyataaan>
End Sub

# %% [markdown]
# 4. Jika tidak menuliskan kata kunci Public atau Private dari General Procedure -> General Procedure Public
# 5. Jika menggunakan kata kunci private pada awal general
# procedure -> General procedure tersebut sama sekali tidak bisa diakses atau dipanggil
# 6. Procedure Public -> Dapat dipanggil dari form lain. Untuk mengakses atau memanggil Procedure Public cara yang digunakan adalah menggunakan perintah Call

# %%
Call <Procedure_Name>(Parameter>

# %% [markdown]
# atau cukup

# %%
Call <Procedure_Name>

# %% [markdown]
# Procedure dapat menerima argument melalui nilai (by value) atau juga reference (by reference). Jika menggunakan by value, nilai pada argument tidak berubah. Sedangkan jika menggunakan by reference, nilai argument yang digunakan dapat berubah sesuai dengan perintah dalam procedure.
#
# Secara default, argument dimasukkan melalui nilai (by value) dapat  menggunakan kata kunci ByVal dan ByRef untuk By Reference.

# %%
[ByVal|ByRef] variabelname as type

# %% [markdown]
# Procedure dengan argument di passing sebagai value

# %%
Sub HitungVal(byVal as Decimal)
  A+=1
  textAkhir.text=a
end sub

# %% [markdown]
# Procedure dengan argument di passing sebagai value

# %%
Sub HitungRef(byRef as Decimal)
  A+=1
  textAkhir.text=a
end sub

# %% [markdown]
# Pemanggilan procedure

# %%
HitungVal(textAwal.Text)

# %% [markdown]
# <hr>

# %% [markdown]
# <h3><b> Praktikum Procedure 1</b><h3>
#
# <p>1. Buatlah desain form seperti ini:</p>

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# <p>2. Kemudian aturlah pengaturan Properties seperti berikut:</p>

# %% [markdown]
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# <p>3. Double klick pada form, kemudian tuliskan kode sub procedure Bersih:</p>

# %%
Public Class Form1
	Sub Bersih()
		TextBoxKodeBarang.Text = ""
		TextBoxNamaBarang.Text = ""
		TextBoxSatuan.Text = ""
		TextBoxHarga.Text = ""
		TextBoxJumlah.Text = ""
		TextBoxTotalHarga.Text = ""
		TextBoxKodeBarang.Focus()
		TextBoxTotalHarga.Enabled = False
	End Sub

# %% [markdown]
# <p>4. Kemudian panggil sub procedure Bersih di atas dengan cara, double click pada form load ketikkan kode program:</p>

# %%
Private Sub Form1_Load(ByVal sender As System.Object, ByVal e As System.EventArgs) Handles MyBase.Load
	Call Bersih()
End Sub

# %% [markdown]
# <p>5. Panggil sub procedure yang dibuat di atas pada ButtonClear dengan cara, double click pada ButtonClear kemudian ketikkan kode program:</p>

# %%
Private Sub ButtonClear_Click(ByVal sender As System.Object, ByVal e As System.EventArgs) Handles ButtonClear.Click
	Call Bersih()
End Sub

# %% [markdown]
# <p>6. Lalu double click pada ButtonExit, kemudian ketik kode program:</p>

# %%
Private Sub ButtonExit_Click(ByVal sender As System.Object, ByVal e As System.EventArgs) Handles ButtonExit.Click
	Dim Tutup As String
	Tutup = MessageBox.Show("Apakah yakin ingin tutup form ini ?", "Konfirmasi", MessageBoxButtons.YesNo,MessageBoxIcon.Question)
	if Tutup = MsgBoxResult.Yes Then
		End
	Else
		Exit Sub
	End if
End Sub

# %% [markdown]
# <p>7. Jalankan aplikasi dengan menekan tombol F5 atau melalui icon Start Debugging di toolbar atau melalui menu Debug -> Start Debuging.</p>

# %% [markdown]
# <h3><b> Praktikum Procedure 2</b><h3>

# %%
Public Class Form1
    Sub TampilkanPesan()
        ' Ini merupakan prosedur untuk menampilkan pesan.
        kotakList.Items.Add("")
        kotakList.Items.Add("Ini dari prosedur Tampilkan Pesan.")
        kotakList.Items.Add("")
    End Sub

    Private Sub tombolTampil_Click(sender As Object, e As EventArgs) Handles tombolTampil.Click
        ' Menampilkan teks pada kotak list
        kotakList.Items.Add("Ini dari prosedur tombolTampil_Click.")
        kotakList.Items.Add("Sekarang Saya memanggil prosedur TampilkanPesan.")

        ' Memanggil prosedur TampilkanPesan
        TampilkanPesan()

        ' Menampilkan teks kembali pada kotak list
        kotakList.Items.Add("Sekarang Saya kembali di prosedur tombolTampil_Click.")
    End Sub

    Private Sub tombolKeluar_Click(sender As Object, e As EventArgs) Handles tombolKeluar.Click
        Me.Close()
    End Sub
End Class

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# <h3><b> Praktikum Procedure 3</b><h3>

# %%
Public Class Form1
    Sub LampuON()
        ' Menampilkan citra "LampuON"
        PBLampuON.Visible = True

        ' Menyembunyikan citra "LampuOFF"
        PBLampuOFF.Visible = False

        ' Mengubah teks label
        statusLampu.Text = "ON"
    End Sub

    Sub LampuOFF()
        ' Menampilkan citra "LampuFF"
        PBLampuOFF.Visible = True

        ' Menyembunyikan citra "LampuON"
        PBLampuON.Visible = False

        ' Mengubah teks label
        statusLampu.Text = "OFF"
    End Sub

    Private Sub tombolSaklar_Click(sender As Object, e As EventArgs) Handles tombolSaklar.Click
        ' Membalik status lampu
        If PBLampuON.Visible = True Then
            LampuOFF()
        Else
            LampuON()
        End If
    End Sub

    Private Sub tombolKeluar_Click(sender As Object, e As EventArgs) Handles tombolKeluar.Click
        Me.Close()
    End Sub
End Class

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# <h3><b> Praktikum Procedure 4</b><h3>

# %%
Public Class Form1

    Private Sub tombolDemo1_Click(sender As Object, e As EventArgs) Handles tombolDemo1.Click
        'Event handler ini memanggil prosedur TampilNilai,
        'melewatkan 5 sebagai argumen
        kotakList.Items.Clear()
        TampilNilai(5)
    End Sub

    Private Sub tombolDemo2_Click(sender As Object, e As EventArgs) Handles tombolDemo2.Click
        ' Memanggil prosedur TampilNilai beberapa kali,
        ' melewatkan argumen-argumen yang berbeda pada tiap pemanggilan
        kotakList.Items.Clear()
        TampilNilai(5)
        TampilNilai(10)
        TampilNilai(2)
        TampilNilai(16)

        ' Nilai dari sebuah ekspresi dilewatkan kepada
        ' prosedur TampilNilai.
        TampilNilai(3 + 5)
    End Sub

    Private Sub tombolDemo3_Click(sender As Object, e As EventArgs) Handles tombolDemo3.Click
        ' Menggunakan sebuah loop untuk memanggil prosedur TampilNilai
        ' melewatkan sebuah variabel sebagai argumen
        kotakList.Items.Clear()
        Dim intHitung As Integer
        For intHitung = 1 To 10
            TampilNilai(intHitung)
        Next
    End Sub

    Sub TampilNilai(ByVal intAngka As Integer)
        ' Prosedur ini menambahkan sebuah nilai pada kotak list
        kotakList.Items.Add(intAngka.ToString())
    End Sub

    Private Sub tombolKeluar_Click(sender As Object, e As EventArgs) Handles tombolKeluar.Click
        Me.Close()
    End Sub
End Class

# %% [markdown]
# ![Lampu 1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# <h3><b> Praktikum Procedure 5</b><h3>

# %%
Public Class Form1

    Private Sub tombolGo_Click(sender As Object, e As EventArgs) Handles tombolGo.Click
        Dim intAngka As Integer = 100

        kotakList.Items.Add("Di dalam tombolGo_Click, nilai dari " &
        "intAngka adalah " & intAngka.ToString())

        kotakList.Items.Add("Sekarang UbahArg dipanggil:")

        UbahArg(intAngka)

        kotakList.Items.Add("Sekarang kembali ke tombolGo_Click, " &
        "nilai dari intAngka adalah " & intAngka.ToString())
    End Sub

    Sub UbahArg(ByVal intArg As Integer)
        ' Menampilkan nilai dari intArg
        kotakList.Items.Add(" ")
        kotakList.Items.Add("Di dalam prosedur UbahArg, " & "intArg bernilai: " & intArg.ToString())

        kotakList.Items.Add("Saya akan mengubah nilai dari intArg.")

        ' Menugaskan 0 kepada intArg
        intArg = 0

        ' Menampilkan nilai dari intArg
        kotakList.Items.Add("intArg sekarang bernilai: " & intArg.ToString())
        kotakList.Items.Add(" ")
    End Sub

    Private Sub tombolBersih_Click(sender As Object, e As EventArgs) Handles tombolBersih.Click
        kotakList.Items.Clear()
    End Sub

    Private Sub tombolKeluar_Click(sender As Object, e As EventArgs) Handles tombolKeluar.Click
        Me.Close()
    End Sub
End Class

# %% [markdown]
# ![Lampu 1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# <h3><b> Praktikum Procedure 6</b><h3>

# %%
Public Class Form1

    Private Sub tombolGo_Click(sender As Object, e As EventArgs) Handles tombolGo.Click
        Dim intAngka As Integer = 100

        kotakList.Items.Add("Di dalam tombolGo_Click, nilai dari " &
        "intAngka adalah " & intAngka.ToString())

        kotakList.Items.Add("Sekarang UbahArg dipanggil:")

        UbahArg(intAngka)

        kotakList.Items.Add("Sekarang kembali ke tombolGo_Click, " &
        "nilai dari intAngka adalah " & intAngka.ToString())
    End Sub

    Sub UbahArg(ByRef intArg As Integer)
        ' Menampilkan nilai dari intArg
        kotakList.Items.Add(" ")
        kotakList.Items.Add("Di dalam prosedur UbahArg, " & "intArg bernilai: " & intArg.ToString())

        kotakList.Items.Add("Saya akan mengubah nilai dari intArg.")

        ' Menugaskan 0 kepada intArg
        intArg = 0

        ' Menampilkan nilai dari intArg
        kotakList.Items.Add("intArg sekarang bernilai: " & intArg.ToString())
        kotakList.Items.Add(" ")
    End Sub

    Private Sub tombolBersih_Click(sender As Object, e As EventArgs) Handles tombolBersih.Click
        kotakList.Items.Clear()
    End Sub

    Private Sub tombolKeluar_Click(sender As Object, e As EventArgs) Handles tombolKeluar.Click
        Me.Close()
    End Sub
End Class

# %% [markdown]
# ![Lampu 1.JPG](data:image/jpeg;base64,...)
